# %%
import pandas as pd


data = pd.read_csv("../csv/Zobahan_Match.csv")
data
data = data[(data["حریف"]=="استقلال")&(data["بازی در خانه"]==0)]
data.describe()
# Out:
#           گل زده  گل خورده   تفاضل گل     امتیاز  بازی در خانه
# count  27.000000  27.00000  27.000000  27.000000          27.0
# mean    1.037037   1.37037  -0.333333   0.925926           0.0
# std     0.939782   0.92604   1.568929   1.206582           0.0
# min     0.000000   0.00000  -3.000000   0.000000           0.0
# 25%     0.000000   1.00000  -1.000000   0.000000           0.0
# 50%     1.000000   1.00000  -1.000000   0.000000           0.0
# 75%     2.000000   2.00000   0.000000   1.000000           0.0
# max     3.000000   3.00000   3.000000   3.000000           0.0
